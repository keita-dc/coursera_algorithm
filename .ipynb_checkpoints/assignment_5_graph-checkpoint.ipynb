# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx

import time

plt.style.use("ggplot")

# %matplotlib inline

# %% [markdown]
# ## Graph Generator

# %%
def generate_graph(vertices=100, edges=200):
    v = np.array(range(vertices))
    e = np.random.randint(0, vertices, (vertices, 1)).tolist()

    for i in range(edges-vertices):
        vertex = np.random.randint(0, vertices)
        e[vertex].append(np.random.randint(0, vertices))
        
    return [v, e]

# %%
test = generate_graph()

# %%
test_dict = {}
for v in test[0]:
    test_dict[v] = test[1][v]

# %%
G = nx.from_dict_of_lists(test_dict, create_using=nx.DiGraph)

# %%
plt.figure(figsize=(12,12))

nx.draw(G, 
        with_labels=True,
        alpha=0.8)
plt.show()

# %% [markdown]
# ## Breadth First Search

# %%
def bfs(graph, start=0):
    size = len(graph[0])
    if start >= size:
        print("start beyond graph size")
    else:
        color = np.zeros(size)
        discover = np.full(size, np.NAN)
        parent = np.full(size, np.NAN)
        
        color[start] = 1
        discover[start] = 0
        
        queue = []
        queue.append(start)
        
        while queue:
            if len(queue) == 1:
                tail_vertex = queue[0]
                queue = []
                for v in graph[1][tail_vertex]:
                    if color[v] == 0:
                        color[v] = 1
                        discover[v] = discover[tail_vertex] + 1
                        parent[v] = tail_vertex
                        queue.append(v)
                color[tail_vertex] = 2
                
            else:
                tail_vertex = queue[0]
                queue = queue[1:]
                for v in graph[1][tail_vertex]:
                    if color[v] == 0:
                        color[v] = 1
                        discover[v] = discover[tail_vertex] + 1
                        parent[v] = tail_vertex
                        queue.append(v)
                color[tail_vertex] = 2
        
        return [discover, parent]

# %%
bfs(test, 0)
# Out:
# [array([ 0., nan, 11.,  8.,  9.,  6., nan, nan, nan,  4.,  2.,  1., nan,
#          7.,  2., nan, nan,  6.,  4.,  5., nan,  4.,  4.,  5.,  8.,  4.,
#          4.,  6.,  8., nan,  3.,  3.,  3., 10., nan,  1.,  3., 10.,  5.,
#          3.,  9.,  4.,  7., nan, nan, nan, nan, nan,  7.,  7., nan, nan,
#          5.,  5.,  4.,  6.,  6.,  6., nan,  6., nan,  2.,  8.,  5.,  6.,
#          7.,  6., nan, nan,  4., nan,  8., nan,  4.,  5.,  7.,  6.,  4.,
#          7.,  4.,  7.,  3.,  5.,  7.,  3.,  9.,  2.,  6.,  5.,  5.,  6.,
#          6.,  1.,  4.,  4.,  5.,  2., nan,  5., nan]),
#  array([nan, nan, 33., 65., 24., 88., nan, nan, nan, 39., 35.,  0., nan,
#         56., 92., nan, nan, 19., 84., 69., nan, 81., 30., 21., 65., 31.,
#         84., 53., 80., nan, 61., 86., 10., 85., nan,  0., 86., 40., 22.,
#         14.,  3., 81., 59., nan, nan, nan, nan, nan, 17., 76., nan, nan,
#         54., 77., 30., 38., 74., 98., nan, 23., nan, 35., 48., 79., 88.,
#         56., 88., nan, nan, 30., nan, 13., nan, 36., 94., 55., 95., 81.,
#         87., 39.,  5., 10., 79., 56., 96., 28., 11., 53., 94., 26., 98.,
#         82.,  0., 36., 39., 26., 92., nan, 69., nan])]

# %%
def bfs_path(graph, start, end, path=[]):
    size = len(graph[0])
    bfs_result = bfs(graph, start)
    previous_vertex = bfs_result[1][int(end)]
    
    if start == end:
        return [start]
    elif start >= size or end >= size:
        print("start or end beyond graph size")
    elif np.isnan(previous_vertex):
        print("there is no path")
    else:
        bfs_path(graph, start, previous_vertex, path)
        path.append(previous_vertex)
         
        return path

# %%
print(bfs_path(test, 0, 2, []))
# Out:
# [0.0, 92.0, 14.0, 39.0, 94.0, 88.0, 5.0, 80.0, 28.0, 85.0, 33.0]

# %% [markdown]
# ## Depth First Search

# %%
def dfs(graph):
    size = len(graph[0])

    color = np.zeros(size)
    discover = np.full(size, np.NAN)
    finish = np.full(size, np.NAN)
    parent = np.full(size, np.NAN)
    time = 0
    
    for vertex in graph[0]:
        vertex = int(vertex)
        if color[vertex] == 0:
            dfs_visit_result = dfs_visit(graph, vertex, time, color, discover, finish, parent)
            time = dfs_visit_result[0]
            color = dfs_visit_result[1]
            discover = dfs_visit_result[2]
            finish = dfs_visit_result[3]
            parent = dfs_visit_result[4]
            
    return [discover, finish, parent]

# %%
def dfs_visit(graph, vertex, time, color, discover, finish, parent):
    time += 1
    color[vertex] = 1
    discover[vertex] = time
    
    for next_vertex in graph[1][vertex]:
        next_vertex = int(next_vertex)
        if color[next_vertex] == 0:
            parent[next_vertex] = vertex
            dfs_visit_result = dfs_visit(graph, next_vertex, time, color, discover, finish, parent)
            time = dfs_visit_result[0]
            color = dfs_visit_result[1]
            discover = dfs_visit_result[2]
            finish = dfs_visit_result[3]
            parent = dfs_visit_result[4]
    
    color[vertex] = 2
    time += 1
    finish[vertex] = time
    return [time, color, discover, finish, parent]

# %%
dfs(test)
# Out:
# [array([  1.,  60.,  30.,  61., 175., 177., 162., 179.,  28., 145., 106.,
#          22.,  74., 180.,  18., 131.,  41., 143.,  49.,  24.,  71.,  11.,
#          37.,  20., 105.,  38.,  54., 102.,  88.,  55.,  64., 119., 103.,
#         155., 185.,  21., 104., 187.,  53.,  13.,   7.,  91.,  48.,  92.,
#          14.,  51.,  59.,  45.,  17.,  93.,  26.,  15.,   8.,  12., 189.,
#          83.,  72.,   5.,  50.,  63.,  44., 120.,  89.,  75.,   9.,  94.,
#          31.,   2.,  35.,  90.,   3.,  62.,  40.,  46., 191.,  25., 181.,
#          73.,   6.,   4.,  43.,  33.,  10.,  16.,  36.,  19., 161.,  78.,
#          42., 193., 172.,  27., 195.,  65.,  39., 199.,  29.,  23., 142.,
#         196.]),
#  array([174.,  85., 129.,  70., 176., 178., 163., 184., 133., 146., 107.,
#         139.,  77., 183., 149., 132., 118., 144., 112., 137.,  82., 158.,
#         126., 141., 108., 125.,  57., 111., 101.,  56.,  67., 122., 110.,
#         156., 186., 140., 109., 188.,  58., 154., 166.,  98., 113.,  97.,
#         153.,  52.,  86., 114., 150.,  96., 135., 152., 165., 157., 190.,
#          84.,  81., 168.,  87.,  68., 115., 121., 100.,  76., 160.,  95.,
#          32., 171., 128.,  99., 170.,  69., 123.,  47., 192., 136., 182.,
#          80., 167., 169., 116.,  34., 159., 151., 127., 148., 164.,  79.,
#         117., 194., 173., 134., 198.,  66., 124., 200., 130., 138., 147.,
#         197.]),
#  array([nan, 46., 96.,  1., nan, nan, 86., nan, 91., 98., 24., 35., 77.,
#          7., 48.,  8., 72., 98., 42., 97.,  1., 82., 84., 85., 36., 22.,
#         38., 18., 18., 26., 59., 72., 27., 53., nan, 23., 32., nan, 58.,
#         53., 78., 69., 47., 41., 39., 58., 58., 60., 83., 43., 75., 44.,
#         40., 21., nan,  1., 20., 79., 18., 71., 80., 31., 28., 12., 52.,
#         49.,  2.,  0.,  2., 62., 67.,  3., 94., 47., nan, 19., 13., 56.,
#         57., 70., 88.,  2., 64., 51., 68., 14., 52., 77., 16., nan,  0.,
#         50., nan, 30., 25., nan,  8., 11., 85., 92.])]

# %% [markdown]
# ## Strongly Connected Components

# %%
def dfs_scc(graph):
    size = len(graph[0])

    color = np.zeros(size)
    discover = np.full(size, np.NAN)
    finish = np.full(size, np.NAN)
    parent = np.full(size, np.NAN)
    finished_order = []
    time = 0
    trees = []
    
    for vertex in graph[0]:
        vertex = int(vertex)
        tree = []
        
        if color[vertex] == 0:
            dfs_visit_result = dfs_visit_scc(graph, 
                                             vertex, 
                                             time, 
                                             color, 
                                             discover, 
                                             finish,
                                             parent, 
                                             finished_order,
                                             tree
                                            )
            time = dfs_visit_result[0]
            color = dfs_visit_result[1]
            discover = dfs_visit_result[2]
            finish = dfs_visit_result[3]
            parent = dfs_visit_result[4]
            finished_order = dfs_visit_result[5]
            if len(dfs_visit_result[6]) > 0:
                trees.append(dfs_visit_result[6])
            
    return [discover, finish, parent, finished_order, trees]

# %%
def dfs_visit_scc(graph, vertex, time, color, discover, finish, parent, finished_order, tree):
    time += 1
    color[vertex] = 1
    discover[vertex] = time
    
    if len(graph[1][vertex]) == 0:
        color[vertex] = 2
        finished_order.append(vertex)
        tree.append(vertex)

        time += 1
        finish[vertex] = time
        return [time, color, discover, finish, parent, finished_order, tree]        
    
    else:    
        for next_vertex in graph[1][vertex]:
            next_vertex = int(next_vertex)
            if color[next_vertex] == 0:
                parent[next_vertex] = vertex
                dfs_visit_result = dfs_visit_scc(graph, 
                                                 next_vertex,
                                                 time, color,
                                                 discover, 
                                                 finish, 
                                                 parent, 
                                                 finished_order,
                                                 tree
                                                )
                time = dfs_visit_result[0]
                color = dfs_visit_result[1]
                discover = dfs_visit_result[2]
                finish = dfs_visit_result[3]
                parent = dfs_visit_result[4]
                finished_order = dfs_visit_result[5]
                trees = dfs_visit_result[6]

        color[vertex] = 2
        finished_order.append(vertex)
        tree.append(vertex)

        time += 1
        finish[vertex] = time
        return [time, color, discover, finish, parent, finished_order, tree]

# %%
def edge_inversion(edges):
    size = len(edges)
    inverted_edges = [[] for _ in range(size)]
    for i in range(size):
        for tail in edges[i]:
            inverted_edges[tail].append(i)
    
    return inverted_edges

# %%
def scc(graph):
    dfs_result = dfs_scc(graph)
    vertices_order = dfs_result[3]
    vertices_order.reverse()
    
    inverted_graph = [vertices_order, edge_inversion(graph[1])]
    
    inverted_dfs_result = dfs_scc(inverted_graph)
    
    return(dfs_result, inverted_dfs_result)

# %%
dfs(test)[2]
# Out:
# array([nan, 46., 96.,  1., nan, nan, 86., nan, 91., 98., 24., 35., 77.,
#         7., 48.,  8., 72., 98., 42., 97.,  1., 82., 84., 85., 36., 22.,
#        38., 18., 18., 26., 59., 72., 27., 53., nan, 23., 32., nan, 58.,
#        53., 78., 69., 47., 41., 39., 58., 58., 60., 83., 43., 75., 44.,
#        40., 21., nan,  1., 20., 79., 18., 71., 80., 31., 28., 12., 52.,
#        49.,  2.,  0.,  2., 62., 67.,  3., 94., 47., nan, 19., 13., 56.,
#        57., 70., 88.,  2., 64., 51., 68., 14., 52., 77., 16., nan,  0.,
#        50., nan, 30., 25., nan,  8., 11., 85., 92.])

# %%
scc(test)[1][4]
# Out:
# [[95],
#  [92],
#  [99],
#  [89],
#  [74],
#  [54],
#  [37],
#  [34],
#  [7],
#  [13],
#  [76],
#  [5],
#  [4],
#  [32,
#   94,
#   72,
#   31,
#   28,
#   62,
#   69,
#   41,
#   43,
#   49,
#   65,
#   1,
#   3,
#   71,
#   59,
#   23,
#   39,
#   15,
#   98,
#   20,
#   66,
#   44,
#   51,
#   83,
#   96,
#   48,
#   73,
#   35,
#   87,
#   45,
#   11,
#   97,
#   19,
#   75,
#   46,
#   9,
#   56,
#   77,
#   12,
#   17,
#   55,
#   2,
#   90,
#   68,
#   33,
#   67,
#   81,
#   70,
#   79,
#   84,
#   22,
#   25,
#   50,
#   91,
#   8,
#   57,
#   64,
#   82,
#   21,
#   53,
#   58,
#   63,
#   38,
#   26,
#   29,
#   78,
#   40,
#   52,
#   86,
#   6,
#   16,
#   88,
#   80,
#   60,
#   47,
#   42,
#   61,
#   18,
#   27,
#   36,
#   24,
#   10,
#   14,
#   85,
#   30,
#   93,
#   0]]
